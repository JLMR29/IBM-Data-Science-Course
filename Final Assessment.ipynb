# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Name: José Luis Muñoz Reyes
# <br>
# Desired Occupation: Data engineer

# %% [markdown]
# _I am interested in data science because it can be applied to many disciplines. The methods used by data scientist help us understand phenomena more deeply and predict possible future scenaries_

# %% [markdown]
# ### The following code calculates 5+8

# %%
a = 5+8
print("The result is:" + str(a))
# Out:
# The result is:13

# %% [markdown]
# <br>
# A bullet list:
#
# -  Banana
# -  Apple
# -  Coconut
# -  Cherry
# <br>
# <br>
# Now the same list but as a table:
# <br>
#
# | Element Number | Name |
# | -------------- | ---- |
# | 1 | Banana |
# | 2 | Apple |
# | 3 | Coconut |
# | 4 | Cherry |
#
# <br>
# Now a numbered list:
#
# 1. Banana
# 2. Apple
# 3. Coconut
# 4. Cherry
